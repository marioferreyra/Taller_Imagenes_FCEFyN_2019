# %% [markdown]
# **Posibilidad de eliminar contornos por area.**
#
# **Propiedades de Contornos**
#
# cv2.contourArea(cnt): calcula área.
#
# cv2.arcLength(cnt,True): calcula longitud de arco. Puede ser una curva cerrada o no. Si se le pasa True es un contorno.

# %%
# %matplotlib inline

import numpy as np
import cv2
import matplotlib.pyplot as plt

src = cv2.imread('herramientas.jpg')

gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

gray = cv2.GaussianBlur(gray, (7, 7), 3)

t, dst = cv2.threshold(gray, 0, 255, cv2.THRESH_TRIANGLE)

# obtener los contornos
contours, _ = cv2.findContours(dst, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

nueva=cv2.drawContours(src, contours, -1, (0, 0,255), 2)

print('Hay ', len(contours),' totales')

plt.imshow(nueva),plt.title('Todos los contornos')
plt.show()

#cv2.LINE_AA es un tipo de línea recomendado
suma=0
for c in contours:
    area = cv2.contourArea(c)
    if area > 100 and area < 60000:
        cadauna=cv2.drawContours(src, [c], 0, (0, 0,255), 2, cv2.LINE_AA)
        suma=suma+1

plt.imshow(cadauna),plt.title('Solo los contornos deseados')
plt.show()

print('Hay',suma,'objetos')
# Out:
# Hay  5  totales
# Hay 3 objetos

# %% [markdown]
# https://docs.opencv.org/master/d7/d4d/tutorial_py_thresholding.html
#
# https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_contours/py_contours_begin/py_contours_begin.html

# %% [markdown]
# **Ejercicio:** haga que las imágenes se muestren con su color real. Cambien el método de umbralizado inspeccionando el histograma.
#
# **Ejercicio** cuente los objetos de la imagen herramientas1.jpg

# %%
# Cargo imagen y calculo histograma
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('herramientas1.jpg', 0)  # El 0 indica que devuelve imagen en gris directamente

hist = cv2.calcHist([img], [0], None, [256], [0, 256])
plt.plot(hist)
plt.xlabel("Intensidad de Iluminación")
plt.ylabel("Cantidad de Píxeles")
plt.title("Histograma de opencv")
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

src = cv2.imread('herramientas1.jpg')

gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

gray = cv2.GaussianBlur(gray, (7, 7), 3)

t, dst = cv2.threshold(gray, 0, 255, cv2.THRESH_TRIANGLE)

# obtener los contornos
contours, _ = cv2.findContours(dst, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

nueva=cv2.drawContours(src, contours, -1, (0, 0,255), 2)

print('Hay ', len(contours),' totales')

plt.imshow(nueva),plt.title('Todos los contornos')
plt.show()

#cv2.LINE_AA es un tipo de línea recomendado
suma=0
for c in contours:
    area = cv2.contourArea(c)
    if area > 100 and area < 60000:
        cadauna=cv2.drawContours(src, [c], 0, (0, 0,255), 2, cv2.LINE_AA)
        suma=suma+1

plt.imshow(cadauna),plt.title('Solo los contornos deseados')
plt.show()

print('Hay',suma,'objetos')
# Out:
# Hay  8  totales
# Hay 3 objetos
